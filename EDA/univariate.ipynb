# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('train.csv',index_col=0)

# %%
df.sample(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 793                 0       3
# 535                 0       3
# 660                 0       1
# 417                 1       2
# 856                 1       3
#
#                                                         Name     Sex   Age  \
# PassengerId
# 793                                  Sage, Miss. Stella Anna  female   NaN
# 535                                      Cacic, Miss. Marija  female  30.0
# 660                               Newell, Mr. Arthur Webster    male  58.0
# 417          Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0
# 856                               Aks, Mrs. Sam (Leah Rosen)  female  18.0
#
#              SibSp  Parch    Ticket      Fare Cabin Embarked
# PassengerId
# 793              8      2  CA. 2343   69.5500   NaN        S
# 535              0      0    315084    8.6625   NaN        S
# 660              0      2     35273  113.2750   D48        C
# ...

# %% [markdown]
# <h1>1.Categorical Data</h1>

# %% [markdown]
# **a.Countplot**

# %%
sns.countplot(x='Survived',data=df)
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x="Pclass",data=df)
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#meanfare pclass ka nikalne k liye ki hum check kar sake 1 aur 2 me kitna difference h ya 3 me 
df.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
df.groupby('Sex')['Fare'].median()
# Out:
# Sex
# female    23.0
# male      10.5
# Name: Fare, dtype: float64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.countplot(x='Embarked',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df["Embarked"].value_counts().plot(kind="pie",autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <h1>2.numerical data</h1>

# %% [markdown]
# **a.Histogram**

# %%
 import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **b.distplot**

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_3896\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **3. BoxPlot**

# %%
 sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)
